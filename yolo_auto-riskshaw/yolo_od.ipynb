# %%
pip install ultralytics

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.50 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.2/78.2 GB disk)

# %%
# !yolo task=detect mode=train epochs=224 data=/content/drive/MyDrive/drive/website_elements_yolov8/data.yaml model=yolov8m.pt imgsz=419
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 225MB/s]
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/drive/yolov8/output/runs/detect/train/weights/yolov8m_custom.pt conf=0.77 source='/content/drive/MyDrive/10663551-uhd_4096_2160_24fps.mp4'
# Out:
# Ultralytics YOLOv8.2.50 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
#
# video 1/1 (frame 1/244) /content/drive/MyDrive/10663551-uhd_4096_2160_24fps.mp4: 352x640 1 auto-riskshaw, 70.0ms
# video 1/1 (frame 2/244) /content/drive/MyDrive/10663551-uhd_4096_2160_24fps.mp4: 352x640 1 auto-riskshaw, 25.0ms
# video 1/1 (frame 3/244) /content/drive/MyDrive/10663551-uhd_4096_2160_24fps.mp4: 352x640 1 auto-riskshaw, 25.0ms
# video 1/1 (frame 4/244) /content/drive/MyDrive/10663551-uhd_4096_2160_24fps.mp4: 352x640 1 auto-riskshaw, 25.3ms
# video 1/1 (frame 5/244) /content/drive/MyDrive/10663551-uhd_4096_2160_24fps.mp4: 352x640 1 auto-riskshaw, 25.1ms
# video 1/1 (frame 6/244) /content/drive/MyDrive/10663551-uhd_4096_2160_24fps.mp4: 352x640 1 auto-riskshaw, 25.0ms
# video 1/1 (frame 7/244) /content/drive/MyDrive/10663551-uhd_4096_2160_24fps.mp4: 352x640 1 auto-riskshaw, 25.0ms
# ...
